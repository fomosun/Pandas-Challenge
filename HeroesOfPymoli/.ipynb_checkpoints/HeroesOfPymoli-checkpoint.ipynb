# %%
# Dependencies
import pandas as pd
import numpy as np

# %%
# Read with Pandas
# File to Load (Remember to Change These)
file_to_load = "Resources/purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
purchasing_analysis = pd.read_csv(file_to_load)
purchasing_analysis.head(11)
# Out:
#     Purchase ID             SN  Age                 Gender  Item ID  \
# 0             0        Lisim78   20                   Male      108
# 1             1    Lisovynya38   40                   Male      143
# 2             2     Ithergue48   24                   Male       92
# 3             3  Chamassasya86   24                   Male      100
# 4             4      Iskosia90   23                   Male      131
# 5             5        Yalae81   22                   Male       81
# 6             6      Itheria73   36                   Male      169
# 7             7    Iskjaskst81   20                   Male      162
# 8             8      Undjask33   22                   Male       21
# 9             9    Chanosian48   35  Other / Non-Disclosed      136
# 10           10      Inguron55   23                   Male       95
#
#                                     Item Name  Price
# 0   Extraction, Quickblade Of Trembling Hands   3.53
# 1                           Frenzied Scimitar   1.56
# 2                                Final Critic   4.88
# 3                                 Blindscythe   3.27
# 4                                        Fury   1.44
# 5                                   Dreamkiss   3.61
# 6      Interrogator, Blood Blade of the Queen   2.18
# 7                               Abyssal Shard   2.67
# 8                                   Souleater   1.10
# 9                Ghastly Adamantite Protector   3.58
# 10                      Singed Onyx Warscythe   4.74

# %%
### Player Count
#Showing Total Number of Players by using the lenth of SN
total_number_of_player = len(purchasing_analysis ["SN"].value_counts())
Sum_Players = pd.DataFrame({"Total Players": [total_number_of_player]})
Sum_Players
# Out:
#    Total Players
# 0            576

# %%
### Purchasing Analysis (Total).
#* Number of Unique Items
#* Average Purchase Price
#* Total Number of Purchases
#* Total Revenue


#* Number of Unique Items
number_of_unique_items = len((purchasing_analysis["Item ID"]).unique())

#* Average Purchase Price
Average_Purchase_Item = (purchasing_analysis["Price"]).mean()

#* Total Number of Purchases
Total_Number_of_Purchase = (purchasing_analysis["Purchase ID"]).count()


#Total Revenue
total_revenue = (purchasing_analysis["Price"]).sum()


# using data frame to get the summary of all
summary = pd.DataFrame({"Number of Unique Items":[number_of_unique_items],"Average Price":[Average_Purchase_Item],"Number of Purchases": [Total_Number_of_Purchase],"Total Revenue": [total_revenue]})

# Format with currency with dollar sign 2 decimal
summary.style.format({'Average Price':"${:,.2f}",'Total Revenue': '${:,.2f}'})
# Out:
# <style  type="text/css" >
# </style><table id="T_5e98c738_a2de_11ea_8cec_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Number of Unique Items</th>        <th class="col_heading level0 col1" >Average Price</th>        <th class="col_heading level0 col2" >Number of Purchases</th>        <th class="col_heading level0 col3" >Total Revenue</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5e98c738_a2de_11ea_8cec_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_5e98c738_a2de_11ea_8cec_acde48001122row0_col0" class="data row0 col0" >179</td>
#                         <td id="T_5e98c738_a2de_11ea_8cec_acde48001122row0_col1" class="data row0 col1" >$3.05</td>
#                         <td id="T_5e98c738_a2de_11ea_8cec_acde48001122row0_col2" class="data row0 col2" >780</td>
#                         <td id="T_5e98c738_a2de_11ea_8cec_acde48001122row0_col3" class="data row0 col3" >$2,379.77</td>
#             </tr>
#     </tbody></table>

# %%
### Gender Demographics.
#* Percentage and Count of Male Players
#* Percentage and Count of Female Players
#* Percentage and Count of Other / Non-Disclosed

# Purchasing Analysis by Gender(Male, Female,Other/Non-Disclosed)
demographics = purchasing_analysis.groupby("Gender")
demographics_count_gender = demographics.nunique()["SN"]

# demographics by gender and divivde by total players 
percentage_players = demographics_count_gender / total_number_of_player * 100

# Using Data Frame
demographics_gender = pd.DataFrame({"Total Count": demographics_count_gender, "Percentage of Players": percentage_players})


demographics_gender.index.name = None
# Format with currency with dollar sign 2 decimal
demographics_gender.sort_values(["Total Count"], ascending = False).style.format({"Percentage of Players":"{:.2f}%"})
# Out:
# <style  type="text/css" >
# </style><table id="T_5e9fed74_a2de_11ea_ba14_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total Count</th>        <th class="col_heading level0 col1" >Percentage of Players</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5e9fed74_a2de_11ea_ba14_acde48001122level0_row0" class="row_heading level0 row0" >Male</th>
#                         <td id="T_5e9fed74_a2de_11ea_ba14_acde48001122row0_col0" class="data row0 col0" >484</td>
#                         <td id="T_5e9fed74_a2de_11ea_ba14_acde48001122row0_col1" class="data row0 col1" >84.03%</td>
#             </tr>
#             <tr>
#                         <th id="T_5e9fed74_a2de_11ea_ba14_acde48001122level0_row1" class="row_heading level0 row1" >Female</th>
#                         <td id="T_5e9fed74_a2de_11ea_ba14_acde48001122row1_col0" class="data row1 col0" >81</td>
#                         <td id="T_5e9fed74_a2de_11ea_ba14_acde48001122row1_col1" class="data row1 col1" >14.06%</td>
#             </tr>
#             <tr>
#                         <th id="T_5e9fed74_a2de_11ea_ba14_acde48001122level0_row2" class="row_heading level0 row2" >Other / Non-Disclosed</th>
#                         <td id="T_5e9fed74_a2de_11ea_ba14_acde48001122row2_col0" class="data row2 col0" >11</td>
#                         <td id="T_5e9fed74_a2de_11ea_ba14_acde48001122row2_col1" class="data row2 col1" >1.91%</td>
#             </tr>
#     </tbody></table>

# %%
# Purchasing Analysis (Gender)
#* The below each broken by gender
  #* Purchase Count
  #* Average Purchase Price
  #* Total Purchase Value
  #* Average Purchase Total per Person by Gender

 #* Purchase Count(Total)
purchasing = demographics["Purchase ID"].count()

#* Average Purchase Price
average_purchasing_amount = demographics["Price"].mean()

#* Average Purchase Price
average_purchasing_sum = demographics["Price"].sum()

# Average purchase by individual
average_individual = average_purchasing_sum/demographics_count_gender

# using DataFrame
demographics = pd.DataFrame({"Purchase Count": purchasing,"Average Purchase Price": average_purchasing_amount,"Average Purchase Value":average_purchasing_sum,"Avg Purchase Total per Person": average_individual})

# Provide calculation"Gender"
demographics.index.name = "Gender"

# Format with currency with dollar sign 2 decimal
demographics.style.format({"Average Purchase Value":"${:,.2f}","Average Purchase Price":"${:,.2f}","Avg Purchase Total per Person":"${:,.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_5ea20514_a2de_11ea_a764_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Average Purchase Price</th>        <th class="col_heading level0 col2" >Average Purchase Value</th>        <th class="col_heading level0 col3" >Avg Purchase Total per Person</th>    </tr>    <tr>        <th class="index_name level0" >Gender</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5ea20514_a2de_11ea_a764_acde48001122level0_row0" class="row_heading level0 row0" >Female</th>
#                         <td id="T_5ea20514_a2de_11ea_a764_acde48001122row0_col0" class="data row0 col0" >113</td>
#                         <td id="T_5ea20514_a2de_11ea_a764_acde48001122row0_col1" class="data row0 col1" >$3.20</td>
#                         <td id="T_5ea20514_a2de_11ea_a764_acde48001122row0_col2" class="data row0 col2" >$361.94</td>
#                         <td id="T_5ea20514_a2de_11ea_a764_acde48001122row0_col3" class="data row0 col3" >$4.47</td>
#             </tr>
#             <tr>
#                         <th id="T_5ea20514_a2de_11ea_a764_acde48001122level0_row1" class="row_heading level0 row1" >Male</th>
#                         <td id="T_5ea20514_a2de_11ea_a764_acde48001122row1_col0" class="data row1 col0" >652</td>
#                         <td id="T_5ea20514_a2de_11ea_a764_acde48001122row1_col1" class="data row1 col1" >$3.02</td>
#                         <td id="T_5ea20514_a2de_11ea_a764_acde48001122row1_col2" class="data row1 col2" >$1,967.64</td>
#                         <td id="T_5ea20514_a2de_11ea_a764_acde48001122row1_col3" class="data row1 col3" >$4.07</td>
#             </tr>
#             <tr>
#                         <th id="T_5ea20514_a2de_11ea_a764_acde48001122level0_row2" class="row_heading level0 row2" >Other / Non-Disclosed</th>
#                         <td id="T_5ea20514_a2de_11ea_a764_acde48001122row2_col0" class="data row2 col0" >15</td>
#                         <td id="T_5ea20514_a2de_11ea_a764_acde48001122row2_col1" class="data row2 col1" >$3.35</td>
#                         <td id="T_5ea20514_a2de_11ea_a764_acde48001122row2_col2" class="data row2 col2" >$50.19</td>
#                         <td id="T_5ea20514_a2de_11ea_a764_acde48001122row2_col3" class="data row2 col3" >$4.56</td>
#             </tr>
#     </tbody></table>

# %%
### Age Demographics
#* The below each broken into bins of 4 years (i.e. &lt;10, 10-14, 15-19, etc.)
  #* Purchase Count
  #* Average Purchase Price
  #* Total Purchase Value
  #* Average Purchase Total per Person by Age Group

bins_age = ([0, 9.90, 14.90, 19.90, 24.90, 29.90, 34.90, 39.90, 99999])
group_names = (["<10", 
                "10-14", 
                "15-19", 
                "20-24", 
                "25-29", 
                "30-34", 
                "35-39", 
                "40+"])

# Segment and sort age values into bins established above
purchasing_analysis["Age Group"] = pd.cut(purchasing_analysis["Age"], bins_age, labels = group_names)
purchasing_analysis

# Create new data frame with the added "Age Group" and group it
grouped_age = purchasing_analysis.groupby("Age Group")

# Count total players by age category
total_count_age = grouped_age["SN"].nunique()

# Calculate the numbers and percentages by age group
percentage_by_age = (total_count_age/total_number_of_player) * 100

# Using Data frame.
demographics_by_age = pd.DataFrame({"Total Count": total_count_age,"Percentage of Players": percentage_by_age})

# Format with currency with dollar sign 2 decimal
demographics_by_age.index.name = None
demographics_by_age.style.format({"Percentage of Players":"{:,.2f}%"})
# Out:
# <style  type="text/css" >
# </style><table id="T_5ea46930_a2de_11ea_9a85_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total Count</th>        <th class="col_heading level0 col1" >Percentage of Players</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5ea46930_a2de_11ea_9a85_acde48001122level0_row0" class="row_heading level0 row0" ><10</th>
#                         <td id="T_5ea46930_a2de_11ea_9a85_acde48001122row0_col0" class="data row0 col0" >17</td>
#                         <td id="T_5ea46930_a2de_11ea_9a85_acde48001122row0_col1" class="data row0 col1" >2.95%</td>
#             </tr>
#             <tr>
#                         <th id="T_5ea46930_a2de_11ea_9a85_acde48001122level0_row1" class="row_heading level0 row1" >10-14</th>
#                         <td id="T_5ea46930_a2de_11ea_9a85_acde48001122row1_col0" class="data row1 col0" >22</td>
#                         <td id="T_5ea46930_a2de_11ea_9a85_acde48001122row1_col1" class="data row1 col1" >3.82%</td>
#             </tr>
#             <tr>
#                         <th id="T_5ea46930_a2de_11ea_9a85_acde48001122level0_row2" class="row_heading level0 row2" >15-19</th>
#                         <td id="T_5ea46930_a2de_11ea_9a85_acde48001122row2_col0" class="data row2 col0" >107</td>
#                         <td id="T_5ea46930_a2de_11ea_9a85_acde48001122row2_col1" class="data row2 col1" >18.58%</td>
#             </tr>
#             <tr>
#                         <th id="T_5ea46930_a2de_11ea_9a85_acde48001122level0_row3" class="row_heading level0 row3" >20-24</th>
#                         <td id="T_5ea46930_a2de_11ea_9a85_acde48001122row3_col0" class="data row3 col0" >258</td>
#                         <td id="T_5ea46930_a2de_11ea_9a85_acde48001122row3_col1" class="data row3 col1" >44.79%</td>
#             </tr>
#             <tr>
#                         <th id="T_5ea46930_a2de_11ea_9a85_acde48001122level0_row4" class="row_heading level0 row4" >25-29</th>
#                         <td id="T_5ea46930_a2de_11ea_9a85_acde48001122row4_col0" class="data row4 col0" >77</td>
#                         <td id="T_5ea46930_a2de_11ea_9a85_acde48001122row4_col1" class="data row4 col1" >13.37%</td>
#             </tr>
#             <tr>
#                         <th id="T_5ea46930_a2de_11ea_9a85_acde48001122level0_row5" class="row_heading level0 row5" >30-34</th>
#                         <td id="T_5ea46930_a2de_11ea_9a85_acde48001122row5_col0" class="data row5 col0" >52</td>
#                         <td id="T_5ea46930_a2de_11ea_9a85_acde48001122row5_col1" class="data row5 col1" >9.03%</td>
#             </tr>
#             <tr>
#                         <th id="T_5ea46930_a2de_11ea_9a85_acde48001122level0_row6" class="row_heading level0 row6" >35-39</th>
#                         <td id="T_5ea46930_a2de_11ea_9a85_acde48001122row6_col0" class="data row6 col0" >31</td>
#                         <td id="T_5ea46930_a2de_11ea_9a85_acde48001122row6_col1" class="data row6 col1" >5.38%</td>
#             </tr>
#             <tr>
#                         <th id="T_5ea46930_a2de_11ea_9a85_acde48001122level0_row7" class="row_heading level0 row7" >40+</th>
#                         <td id="T_5ea46930_a2de_11ea_9a85_acde48001122row7_col0" class="data row7 col0" >12</td>
#                         <td id="T_5ea46930_a2de_11ea_9a85_acde48001122row7_col1" class="data row7 col1" >2.08%</td>
#             </tr>
#     </tbody></table>

# %%
### Purchasing Analysis (Gender)

#* The below each broken by gender
  #* Purchase Count
  #* Average Purchase Price
  #* Total Purchase Value
  #* Average Purchase Total per Person by Gender

#Purchase Count
age_purchase_count = grouped_age["Purchase ID"].count()
average_purchase_price = grouped_age["Price"].mean()
sum_purchase = grouped_age["Price"].sum()

# average purchase per person in the age group 
average_purchase_group = sum_purchase/total_count_age

# Create data frame with obtained values
demographics_by_age = pd.DataFrame({"Purchase Count": age_purchase_count,"Average Purchase Price": average_purchase_price,"Total Purchase Value":sum_purchase,"Average Purchase Total per Person": average_purchase_group})

# Format the data frame with to give index name Age Ranges
demographics_by_age.index.name = 'Age Ranges'

# Format with currency with dollar sign 2 decimal
demographics_by_age.style.format({"Average Purchase Price":"${:,.2f}","Total Purchase Value":"${:,.2f}","Average Purchase Total per Person":"${:,.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_5ea64390_a2de_11ea_afbf_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Average Purchase Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>        <th class="col_heading level0 col3" >Average Purchase Total per Person</th>    </tr>    <tr>        <th class="index_name level0" >Age Ranges</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5ea64390_a2de_11ea_afbf_acde48001122level0_row0" class="row_heading level0 row0" ><10</th>
#                         <td id="T_5ea64390_a2de_11ea_afbf_acde48001122row0_col0" class="data row0 col0" >23</td>
#                         <td id="T_5ea64390_a2de_11ea_afbf_acde48001122row0_col1" class="data row0 col1" >$3.35</td>
#                         <td id="T_5ea64390_a2de_11ea_afbf_acde48001122row0_col2" class="data row0 col2" >$77.13</td>
#                         <td id="T_5ea64390_a2de_11ea_afbf_acde48001122row0_col3" class="data row0 col3" >$4.54</td>
#             </tr>
#             <tr>
#                         <th id="T_5ea64390_a2de_11ea_afbf_acde48001122level0_row1" class="row_heading level0 row1" >10-14</th>
#                         <td id="T_5ea64390_a2de_11ea_afbf_acde48001122row1_col0" class="data row1 col0" >28</td>
#                         <td id="T_5ea64390_a2de_11ea_afbf_acde48001122row1_col1" class="data row1 col1" >$2.96</td>
#                         <td id="T_5ea64390_a2de_11ea_afbf_acde48001122row1_col2" class="data row1 col2" >$82.78</td>
#                         <td id="T_5ea64390_a2de_11ea_afbf_acde48001122row1_col3" class="data row1 col3" >$3.76</td>
#             </tr>
#             <tr>
#                         <th id="T_5ea64390_a2de_11ea_afbf_acde48001122level0_row2" class="row_heading level0 row2" >15-19</th>
#                         <td id="T_5ea64390_a2de_11ea_afbf_acde48001122row2_col0" class="data row2 col0" >136</td>
#                         <td id="T_5ea64390_a2de_11ea_afbf_acde48001122row2_col1" class="data row2 col1" >$3.04</td>
#                         <td id="T_5ea64390_a2de_11ea_afbf_acde48001122row2_col2" class="data row2 col2" >$412.89</td>
#                         <td id="T_5ea64390_a2de_11ea_afbf_acde48001122row2_col3" class="data row2 col3" >$3.86</td>
#             </tr>
#             <tr>
#                         <th id="T_5ea64390_a2de_11ea_afbf_acde48001122level0_row3" class="row_heading level0 row3" >20-24</th>
#                         <td id="T_5ea64390_a2de_11ea_afbf_acde48001122row3_col0" class="data row3 col0" >365</td>
#                         <td id="T_5ea64390_a2de_11ea_afbf_acde48001122row3_col1" class="data row3 col1" >$3.05</td>
#                         <td id="T_5ea64390_a2de_11ea_afbf_acde48001122row3_col2" class="data row3 col2" >$1,114.06</td>
#                         <td id="T_5ea64390_a2de_11ea_afbf_acde48001122row3_col3" class="data row3 col3" >$4.32</td>
#             </tr>
#             <tr>
#                         <th id="T_5ea64390_a2de_11ea_afbf_acde48001122level0_row4" class="row_heading level0 row4" >25-29</th>
#                         <td id="T_5ea64390_a2de_11ea_afbf_acde48001122row4_col0" class="data row4 col0" >101</td>
#                         <td id="T_5ea64390_a2de_11ea_afbf_acde48001122row4_col1" class="data row4 col1" >$2.90</td>
#                         <td id="T_5ea64390_a2de_11ea_afbf_acde48001122row4_col2" class="data row4 col2" >$293.00</td>
#                         <td id="T_5ea64390_a2de_11ea_afbf_acde48001122row4_col3" class="data row4 col3" >$3.81</td>
#             </tr>
#             <tr>
#                         <th id="T_5ea64390_a2de_11ea_afbf_acde48001122level0_row5" class="row_heading level0 row5" >30-34</th>
#                         <td id="T_5ea64390_a2de_11ea_afbf_acde48001122row5_col0" class="data row5 col0" >73</td>
#                         <td id="T_5ea64390_a2de_11ea_afbf_acde48001122row5_col1" class="data row5 col1" >$2.93</td>
#                         <td id="T_5ea64390_a2de_11ea_afbf_acde48001122row5_col2" class="data row5 col2" >$214.00</td>
#                         <td id="T_5ea64390_a2de_11ea_afbf_acde48001122row5_col3" class="data row5 col3" >$4.12</td>
#             </tr>
#             <tr>
#                         <th id="T_5ea64390_a2de_11ea_afbf_acde48001122level0_row6" class="row_heading level0 row6" >35-39</th>
#                         <td id="T_5ea64390_a2de_11ea_afbf_acde48001122row6_col0" class="data row6 col0" >41</td>
#                         <td id="T_5ea64390_a2de_11ea_afbf_acde48001122row6_col1" class="data row6 col1" >$3.60</td>
#                         <td id="T_5ea64390_a2de_11ea_afbf_acde48001122row6_col2" class="data row6 col2" >$147.67</td>
#                         <td id="T_5ea64390_a2de_11ea_afbf_acde48001122row6_col3" class="data row6 col3" >$4.76</td>
#             </tr>
#             <tr>
#                         <th id="T_5ea64390_a2de_11ea_afbf_acde48001122level0_row7" class="row_heading level0 row7" >40+</th>
#                         <td id="T_5ea64390_a2de_11ea_afbf_acde48001122row7_col0" class="data row7 col0" >13</td>
#                         <td id="T_5ea64390_a2de_11ea_afbf_acde48001122row7_col1" class="data row7 col1" >$2.94</td>
#                         <td id="T_5ea64390_a2de_11ea_afbf_acde48001122row7_col2" class="data row7 col2" >$38.24</td>
#                         <td id="T_5ea64390_a2de_11ea_afbf_acde48001122row7_col3" class="data row7 col3" >$3.19</td>
#             </tr>
#     </tbody></table>

# %%
### Top Spenders

#* Identify the the top 5 spenders in the game by total purchase value, then list (in a table):
  #* SN
  #* Purchase Count
  #* Average Purchase Price
  #* Total Purchase Value
    
# Group purchase data by SN(Screen name)
top_spender = purchasing_analysis.groupby("SN")

# Count the total purchases by name
count_spender = top_spender["Purchase ID"].count()

# Calculate the average purchase by name 
average_price_spender = top_spender["Price"].mean()

# Calculate purchase  
sum_spender = top_spender["Price"].sum()

# Create data frame with obtained values
top_spenders = pd.DataFrame({"Purchase Count": count_spender,"Average Purchase Price": average_price_spender,"Total Purchase Value":sum_spender})

# filter in descending order to obtain top 5 spender
formatted_spenders = top_spenders.sort_values(["Total Purchase Value"], ascending = False).head()

# Format with currency with dollar sign 2 decimal
formatted_spenders.style.format({"Average Purchase Price":"${:,.2f}","Total Purchase Value":"${:,.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_5eae260a_a2de_11ea_98ad_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Average Purchase Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>    </tr>    <tr>        <th class="index_name level0" >SN</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5eae260a_a2de_11ea_98ad_acde48001122level0_row0" class="row_heading level0 row0" >Lisosia93</th>
#                         <td id="T_5eae260a_a2de_11ea_98ad_acde48001122row0_col0" class="data row0 col0" >5</td>
#                         <td id="T_5eae260a_a2de_11ea_98ad_acde48001122row0_col1" class="data row0 col1" >$3.79</td>
#                         <td id="T_5eae260a_a2de_11ea_98ad_acde48001122row0_col2" class="data row0 col2" >$18.96</td>
#             </tr>
#             <tr>
#                         <th id="T_5eae260a_a2de_11ea_98ad_acde48001122level0_row1" class="row_heading level0 row1" >Idastidru52</th>
#                         <td id="T_5eae260a_a2de_11ea_98ad_acde48001122row1_col0" class="data row1 col0" >4</td>
#                         <td id="T_5eae260a_a2de_11ea_98ad_acde48001122row1_col1" class="data row1 col1" >$3.86</td>
#                         <td id="T_5eae260a_a2de_11ea_98ad_acde48001122row1_col2" class="data row1 col2" >$15.45</td>
#             </tr>
#             <tr>
#                         <th id="T_5eae260a_a2de_11ea_98ad_acde48001122level0_row2" class="row_heading level0 row2" >Chamjask73</th>
#                         <td id="T_5eae260a_a2de_11ea_98ad_acde48001122row2_col0" class="data row2 col0" >3</td>
#                         <td id="T_5eae260a_a2de_11ea_98ad_acde48001122row2_col1" class="data row2 col1" >$4.61</td>
#                         <td id="T_5eae260a_a2de_11ea_98ad_acde48001122row2_col2" class="data row2 col2" >$13.83</td>
#             </tr>
#             <tr>
#                         <th id="T_5eae260a_a2de_11ea_98ad_acde48001122level0_row3" class="row_heading level0 row3" >Iral74</th>
#                         <td id="T_5eae260a_a2de_11ea_98ad_acde48001122row3_col0" class="data row3 col0" >4</td>
#                         <td id="T_5eae260a_a2de_11ea_98ad_acde48001122row3_col1" class="data row3 col1" >$3.40</td>
#                         <td id="T_5eae260a_a2de_11ea_98ad_acde48001122row3_col2" class="data row3 col2" >$13.62</td>
#             </tr>
#             <tr>
#                         <th id="T_5eae260a_a2de_11ea_98ad_acde48001122level0_row4" class="row_heading level0 row4" >Iskadarya95</th>
#                         <td id="T_5eae260a_a2de_11ea_98ad_acde48001122row4_col0" class="data row4 col0" >3</td>
#                         <td id="T_5eae260a_a2de_11ea_98ad_acde48001122row4_col1" class="data row4 col1" >$4.37</td>
#                         <td id="T_5eae260a_a2de_11ea_98ad_acde48001122row4_col2" class="data row4 col2" >$13.10</td>
#             </tr>
#     </tbody></table>

# %%
### Most Popular Items

#* Identify the 5 most popular items by purchase count, then list (in a table):
  #* Item ID
  #* Item Name
  #* Purchase Count
  #* Item Price
  #* Total Purchase Value
    

#get the item id,item name,price (DataFrame) 
most_items_df = purchasing_analysis[["Item ID", "Item Name", "Price"]]
most_item_stats = most_items_df.groupby(["Item ID","Item Name"])

#write the result to two columns
most_purchase_count_item = most_item_stats["Price"].count()
Total_purchase_value = (most_item_stats["Price"].sum())

# Find individual item price
item_price = Total_purchase_value/most_purchase_count_item


# Create data frame with obtained values
most_popular_items = pd.DataFrame({"Purchase Count": most_purchase_count_item,"Item Price": item_price,"Total Purchase Value":Total_purchase_value})

# Sort in descending order to obtain top spender names and provide top 5 item names
popular_formatted = most_popular_items.sort_values(["Purchase Count"], ascending=False).head()

# Format with currency with dollar sign 2 decimal
popular_formatted.style.format({"Item Price":"${:,.2f}","Total Purchase Value":"${:,.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_5eb107da_a2de_11ea_b55d_acde48001122" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Item Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>    </tr>    <tr>        <th class="index_name level0" >Item ID</th>        <th class="index_name level1" >Item Name</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5eb107da_a2de_11ea_b55d_acde48001122level0_row0" class="row_heading level0 row0" >92</th>
#                         <th id="T_5eb107da_a2de_11ea_b55d_acde48001122level1_row0" class="row_heading level1 row0" >Final Critic</th>
#                         <td id="T_5eb107da_a2de_11ea_b55d_acde48001122row0_col0" class="data row0 col0" >13</td>
#                         <td id="T_5eb107da_a2de_11ea_b55d_acde48001122row0_col1" class="data row0 col1" >$4.61</td>
#                         <td id="T_5eb107da_a2de_11ea_b55d_acde48001122row0_col2" class="data row0 col2" >$59.99</td>
#             </tr>
#             <tr>
#                         <th id="T_5eb107da_a2de_11ea_b55d_acde48001122level0_row1" class="row_heading level0 row1" >178</th>
#                         <th id="T_5eb107da_a2de_11ea_b55d_acde48001122level1_row1" class="row_heading level1 row1" >Oathbreaker, Last Hope of the Breaking Storm</th>
#                         <td id="T_5eb107da_a2de_11ea_b55d_acde48001122row1_col0" class="data row1 col0" >12</td>
#                         <td id="T_5eb107da_a2de_11ea_b55d_acde48001122row1_col1" class="data row1 col1" >$4.23</td>
#                         <td id="T_5eb107da_a2de_11ea_b55d_acde48001122row1_col2" class="data row1 col2" >$50.76</td>
#             </tr>
#             <tr>
#                         <th id="T_5eb107da_a2de_11ea_b55d_acde48001122level0_row2" class="row_heading level0 row2" >145</th>
#                         <th id="T_5eb107da_a2de_11ea_b55d_acde48001122level1_row2" class="row_heading level1 row2" >Fiery Glass Crusader</th>
#                         <td id="T_5eb107da_a2de_11ea_b55d_acde48001122row2_col0" class="data row2 col0" >9</td>
#                         <td id="T_5eb107da_a2de_11ea_b55d_acde48001122row2_col1" class="data row2 col1" >$4.58</td>
#                         <td id="T_5eb107da_a2de_11ea_b55d_acde48001122row2_col2" class="data row2 col2" >$41.22</td>
#             </tr>
#             <tr>
#                         <th id="T_5eb107da_a2de_11ea_b55d_acde48001122level0_row3" class="row_heading level0 row3" >132</th>
#                         <th id="T_5eb107da_a2de_11ea_b55d_acde48001122level1_row3" class="row_heading level1 row3" >Persuasion</th>
#                         <td id="T_5eb107da_a2de_11ea_b55d_acde48001122row3_col0" class="data row3 col0" >9</td>
#                         <td id="T_5eb107da_a2de_11ea_b55d_acde48001122row3_col1" class="data row3 col1" >$3.22</td>
#                         <td id="T_5eb107da_a2de_11ea_b55d_acde48001122row3_col2" class="data row3 col2" >$28.99</td>
#             </tr>
#             <tr>
#                         <th id="T_5eb107da_a2de_11ea_b55d_acde48001122level0_row4" class="row_heading level0 row4" >108</th>
#                         <th id="T_5eb107da_a2de_11ea_b55d_acde48001122level1_row4" class="row_heading level1 row4" >Extraction, Quickblade Of Trembling Hands</th>
#                         <td id="T_5eb107da_a2de_11ea_b55d_acde48001122row4_col0" class="data row4 col0" >9</td>
#                         <td id="T_5eb107da_a2de_11ea_b55d_acde48001122row4_col1" class="data row4 col1" >$3.53</td>
#                         <td id="T_5eb107da_a2de_11ea_b55d_acde48001122row4_col2" class="data row4 col2" >$31.77</td>
#             </tr>
#     </tbody></table>

# %%
### Most Profitable Items

#* Identify the 5 most profitable items by total purchase value, then list (in a table):
  #* Item ID
  #* Item Name
  #* Purchase Count
  #* Item Price
  #* Total Purchase Value
    
   # Sort by most profitable (highest Total Purchase Value=most profitable) in descending order
most_profitable_items_df = most_popular_items.sort_values(['Total Purchase Value'], ascending=False).head()

# Format into $0.00 for price and total purchase value
most_profitable_items_df.style.format({"Item Price":"${:,.2f}","Total Purchase Value":"${:,.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_bf5a5cd0_a2de_11ea_a328_acde48001122" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Item Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>    </tr>    <tr>        <th class="index_name level0" >Item ID</th>        <th class="index_name level1" >Item Name</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_bf5a5cd0_a2de_11ea_a328_acde48001122level0_row0" class="row_heading level0 row0" >92</th>
#                         <th id="T_bf5a5cd0_a2de_11ea_a328_acde48001122level1_row0" class="row_heading level1 row0" >Final Critic</th>
#                         <td id="T_bf5a5cd0_a2de_11ea_a328_acde48001122row0_col0" class="data row0 col0" >13</td>
#                         <td id="T_bf5a5cd0_a2de_11ea_a328_acde48001122row0_col1" class="data row0 col1" >$4.61</td>
#                         <td id="T_bf5a5cd0_a2de_11ea_a328_acde48001122row0_col2" class="data row0 col2" >$59.99</td>
#             </tr>
#             <tr>
#                         <th id="T_bf5a5cd0_a2de_11ea_a328_acde48001122level0_row1" class="row_heading level0 row1" >178</th>
#                         <th id="T_bf5a5cd0_a2de_11ea_a328_acde48001122level1_row1" class="row_heading level1 row1" >Oathbreaker, Last Hope of the Breaking Storm</th>
#                         <td id="T_bf5a5cd0_a2de_11ea_a328_acde48001122row1_col0" class="data row1 col0" >12</td>
#                         <td id="T_bf5a5cd0_a2de_11ea_a328_acde48001122row1_col1" class="data row1 col1" >$4.23</td>
#                         <td id="T_bf5a5cd0_a2de_11ea_a328_acde48001122row1_col2" class="data row1 col2" >$50.76</td>
#             </tr>
#             <tr>
#                         <th id="T_bf5a5cd0_a2de_11ea_a328_acde48001122level0_row2" class="row_heading level0 row2" >82</th>
#                         <th id="T_bf5a5cd0_a2de_11ea_a328_acde48001122level1_row2" class="row_heading level1 row2" >Nirvana</th>
#                         <td id="T_bf5a5cd0_a2de_11ea_a328_acde48001122row2_col0" class="data row2 col0" >9</td>
#                         <td id="T_bf5a5cd0_a2de_11ea_a328_acde48001122row2_col1" class="data row2 col1" >$4.90</td>
#                         <td id="T_bf5a5cd0_a2de_11ea_a328_acde48001122row2_col2" class="data row2 col2" >$44.10</td>
#             </tr>
#             <tr>
#                         <th id="T_bf5a5cd0_a2de_11ea_a328_acde48001122level0_row3" class="row_heading level0 row3" >145</th>
#                         <th id="T_bf5a5cd0_a2de_11ea_a328_acde48001122level1_row3" class="row_heading level1 row3" >Fiery Glass Crusader</th>
#                         <td id="T_bf5a5cd0_a2de_11ea_a328_acde48001122row3_col0" class="data row3 col0" >9</td>
#                         <td id="T_bf5a5cd0_a2de_11ea_a328_acde48001122row3_col1" class="data row3 col1" >$4.58</td>
#                         <td id="T_bf5a5cd0_a2de_11ea_a328_acde48001122row3_col2" class="data row3 col2" >$41.22</td>
#             </tr>
#             <tr>
#                         <th id="T_bf5a5cd0_a2de_11ea_a328_acde48001122level0_row4" class="row_heading level0 row4" >103</th>
#                         <th id="T_bf5a5cd0_a2de_11ea_a328_acde48001122level1_row4" class="row_heading level1 row4" >Singed Scalpel</th>
#                         <td id="T_bf5a5cd0_a2de_11ea_a328_acde48001122row4_col0" class="data row4 col0" >8</td>
#                         <td id="T_bf5a5cd0_a2de_11ea_a328_acde48001122row4_col1" class="data row4 col1" >$4.35</td>
#                         <td id="T_bf5a5cd0_a2de_11ea_a328_acde48001122row4_col2" class="data row4 col2" >$34.80</td>
#             </tr>
#     </tbody></table>
